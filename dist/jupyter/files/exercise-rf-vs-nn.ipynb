# %% [markdown]
# # Exercise 2: Random Forest vs Neural Network
# Compare two ML models on crater classification.

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
print("Ready!")
# Out:
# Ready!

# %%
X = np.random.rand(500, 10)
y = np.random.randint(0, 2, 500)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, y_train)
rf_acc = accuracy_score(y_test, rf.predict(X_test))
print(f"Random Forest: {rf_acc:.4f}")

nn = MLPClassifier(hidden_layer_sizes=(32,32), max_iter=500)
nn.fit(X_train, y_train)
nn_acc = accuracy_score(y_test, nn.predict(X_test))
print(f"Neural Network: {nn_acc:.4f}")
# Out:
# Random Forest: 0.5500
# Neural Network: 0.5400
# /home/tsatsral/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
matplotlib.use("Agg")

plt.figure(figsize=(8,5))
plt.bar(["Random Forest", "Neural Network"], [rf_acc, nn_acc], color=["steelblue", "coral"])
plt.ylabel("Accuracy")
plt.title("Model Comparison")
plt.ylim(0, 1)
for i, v in enumerate([rf_acc, nn_acc]):
    plt.text(i, v+0.01, f"{v:.4f}", ha="center")
plt.savefig("model_comparison.png", dpi=100, bbox_inches="tight")
plt.show()
print("Done!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 matplotlib.use("Agg")
#       3
#       4 plt.figure(figsize=(8,5))
#       5 plt.bar(["Random Forest", "Neural Network"], [rf_acc, nn_acc], color=["steelblue", "coral"])
#
# NameError: name 'matplotlib' is not defined
